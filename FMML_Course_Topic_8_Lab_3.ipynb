# %% [markdown]
# <a href="https://colab.research.google.com/github/Shanmuka807/fmml-assaignments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-02 06:55:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   244MB/s    in 0.3s
#
# 2023-05-02 06:55:09 (244 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 462    1607.06025v2  Natural Language Inference is an important tas...    cs
# 21498   0707.3536v1  Dendrograms used in data analysis are ultramet...  stat
# 4362   1603.02736v1  A variety of real-world tasks involve the clas...  stat
# 8869   1606.07137v1  We present a simple approach for automatically...    cs
# 6357   1611.06863v1  Existing methods for structure discovery in ti...  stat
# ...             ...                                                ...   ...
# 12894  1803.03254v1  We present semi-supervised deep learning appro...    cs
# 29743  1710.04097v1  Radon transform and its inverse operation are ...    cs
# 7525   1802.00043v1  Incremental versions of batch algorithms are o...  stat
# 10373   1301.6705v1  Probabilistic Latent Semantic Analysis is a no...    cs
# 981     1410.3831v1  Deep learning is a broad set of techniques tha...  stat
#
#                                                    title  year  \
# 462    Constructing a Natural Language Inference Data...  2016
# 21498               Degenerating families of dendrograms  2007
# 4362   Discriminative models for robust image classif...  2016
# 8869   Automated Extraction of Number of Subjects in ...  2016
# 6357   Probabilistic structure discovery in time seri...  2016
# ...                                                  ...   ...
# 12894  GONet: A Semi-Supervised Deep Learning Approac...  2018
# 29743           Local Radon Descriptors for Image Search  2017
# 7525       Incremental kernel PCA and the Nyström method  2018
# 10373             Probabilistic Latent Semantic Analysis  2013
# 981    An exact mapping between the Variational Renor...  2014
#
#                                                 keywords
# 462    [inference, important, understanding, concerne...
# 21498  [dendrograms, ultrametric, nonarchimedean, rep...
# 4362   [classification, determined, categories, desig...
# 8869   [automatically, extracting, randomised, contro...
# 6357   [structure, discovery, construct, interpretabl...
# ...                                                  ...
# 12894  [supervised, approaches, traversability, estim...
# 29743  [transform, operation, important, techniques, ...
# 7525   [incremental, algorithms, increased, efficienc...
# 10373  [probabilistic, statistical, technique, occurr...
# 981    [techniques, representation, automatically, st...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 462      [inference, important, understanding, concerne...
# 21498    [dendrograms, ultrametric, nonarchimedean, rep...
# 4362     [classification, determined, categories, desig...
# 8869     [automatically, extracting, randomised, contro...
# 6357     [structure, discovery, construct, interpretabl...
#                                ...
# 6269     [framework, distributed, environment, partitio...
# 4545     [artificial, intelligence, uncertainty, partia...
# 13686    [deterministic, advantage, unfortunately, inte...
# 32701    [screening, collections, unlabeled, important,...
# 7846     [detection, frequency, detrended, fluctuation,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8741 words.
# Out of those 4557 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="dcc539b9-1950-4f34-953a-69d4299fb065" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dcc539b9-1950-4f34-953a-69d4299fb065")) {                    Plotly.newPlot(                        "dcc539b9-1950-4f34-953a-69d4299fb065",                        [{"x":["generating","constructing","construction","embedding","understanding","sentences","concerned","classifier","furthermore","generative","classification","generated","classifying","necessarily","including","inference","accuracies","distinguishability","comparing","hypothesis","important","characteristics","completed","projective","parameter","framework","representation","ultrametric","associated","calculate","stochastic","dendrogram","algebraic","implications","distributions","robustness","applications","complementary","dimensional","algorithms","minimizing","underlying","dissertation","explicitly","discriminative","structure","distortions","information","probabilistic","specifically","experiments","available","complexity","graphical","structures","insufficient","particularly","insufficiency","iterative","categories","approximate","challenge","development","resulting","determined","correlated","projections","designing","correlations","conditional","probability","representations","significant","acquisition","answering","techniques","candidates","randomised","contextual","abstracts","automatically","candidate","structural","annotated","processing","summarisation","automated","supervised","performed","extracting","extraction","controlled","interpretable","optimization","estimates","restricts","posterior","procedure","introduce","typically","inferring","regression","construct","solutions","compositional","discovery","confident","uncertainty","preserving","additional","predictions","resolution","prediction","satellite","directions","increased","approaches","availability","outperform","challenges","boundaries","segmentation","introducing","translation","recognition","unweighted","successfully","averaging","investigated","stochastically","different","ensembles","performance","convolutional","artificial","confidence","phenomenon","improvement","assumptions","application","guarantees","convergent","consisting","maximization","estimation","expectation","compressed","deconvolution","spatiotemporally","innovations","theoretical","transition","efficient","transient","simulation","advantage","frequently","conducted","presented","structured","constraint","dictionary","developed","addresses","computational","efficiency","encouraged","difference","extensive","suppression","regularization","categorization","meanwhile","efficiently","properties","literature","observation","partitioning","sufficiently","asymptotic","statistics","algorithm","significantly","synthetic","numerical","processes","considered","estimated","densities","iteration","clustering","initialization","knowledge","according","dissimilarity","stationary","observations","nonparametric","guaranteed","estimating"],"y":[114,36,70,108,157,74,20,168,154,118,502,167,37,18,254,209,25,1,74,38,335,93,5,8,123,588,379,0,126,22,135,0,11,31,118,97,454,38,188,588,40,114,3,68,94,314,18,675,161,165,601,313,248,65,132,15,73,1,73,79,101,149,111,153,38,29,28,46,30,100,174,227,270,33,44,375,26,2,49,7,170,59,60,75,271,3,102,206,121,59,128,41,28,332,77,4,41,126,336,95,25,117,89,145,28,53,3,78,46,124,89,104,241,11,44,40,428,34,92,120,36,217,57,110,382,1,74,18,45,3,738,15,878,409,138,45,22,147,65,229,60,10,44,34,201,24,32,13,1,2,138,32,414,4,61,90,41,77,183,93,96,55,208,50,278,160,6,50,170,11,82,31,24,162,227,109,79,21,17,13,64,823,252,136,89,105,109,69,9,34,150,24,357,86,10,25,94,13,35,63],"type":"bar"},{"x":["generating","constructing","construction","embedding" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4557,), (4557, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7866666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>From</span> <span style=''>First</span> <span style=''>Order</span> <span style=''>Logic</span> <span style=''>to</span> <span style=''>Assertional</span> <span style=''>Logic</span> <br/><br/><span style=''>First</span> <span style=''>Order</span> <span style=''>Logic</span> <span style=''>(FOL)</span> <span style=''>is</span> <span style=''>widely</span> <span style=''>regarded</span> <span style=''>as</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>foundations</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.373076923076923);'>knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.42213883677298314);'>representation</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923076);'>Nevertheless</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>FOL</span> <span style=''>has</span> <span style=''>several</span> <span style=''>critical</span> <span style=''>issues</span> <span style=''>for</span> <span style=''>this</span> <span style=''>purpose</span> <span style=''>Instead</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>called</span> <span style=''>assertional</span> <span style=''>logic</span> <span style=''>in</span> <span style=''>which</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>syntactic</span> <span style=''>objects</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>categorized</span> <span style=''>as</span> <span style=''>set</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>constructs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individuals</span> <span style=''>concepts</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5076923076923077);'>operators</span> <span style=''>and</span> <span style=''>all</span> <span style=''>kinds</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.373076923076923);'>knowledge</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formalized</span> <span style=''>by</span> <span style=''>equality</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>assertions</span> <span style=''>We</span> <span style=''>first</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>primitive</span> <span style=''>form</span> <span style=''>of</span> <span style=''>assertional</span> <span style=''>logic</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>minimal</span> <span style=''>assumed</span> <span style='background-color:rgba(0, 255, 0, 0.373076923076923);'>knowledge</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>constructs</span> <span style=''>Then</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style=''>extend</span> <span style=''>it</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555555);'>definitions</span> <span style=''>which</span> <span style=''>are</span> <span style=''>special</span> <span style=''>kinds</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.373076923076923);'>knowledge</span> <span style=''>ie</span> <span style='backgr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Completely</span> <span style=''>random</span> <span style=''>measures</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>block</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>networks</span> <br/><br/><span style=''>Many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>network</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameterize</span> <span style=''>the</span> <span style=''>edge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>by</span> <span style=''>attributing</span> <span style=''>latent</span> <span style=''>traits</span> <span style=''>to</span> <span style=''>the</span> <span style=''>vertices</span> <span style=''>such</span> <span style=''>as</span> <span style=''>block</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>assume</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exchangeability</span> <span style=''>in</span> <span style=''>the</span> <span style=''>sense</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Aldous</span> <span style=''>Hoover</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>theorem</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Empirical</span> <span style=''>studies</span> <span style=''>of</span> <span style=''>networks</span> <span style=''>indicate</span> <span style=''>that</span> <span style=''>many</span> <span style=''>real</span> <span style=''>world</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>a</span> <span style=''>power</span> <span style=''>law</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>vertices</span> <span style=''>which</span> <span style=''>in</span> <span style=''>turn</span> <span style=''>implies</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>edges</span> <span style=''>scale</span> <span style=''>slower</span> <span style=''>than</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadratically</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>vertices</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamentally</span> <span style=''>irreconcilable</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Aldous</span> <span style=''>Hoover</span> <span style=''>theorem</span> <span style=''>implies</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadratic</span> <span style=''>scaling</span> <span style=''>of</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>edges</span> <span style=''>Recently</span> <span style=''>Caron</span> <span style=''>and</span> <span style=''>Fox</span> <span style=''>(2014)</span> <span style=''>proposed</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exchangeability</span> <span style=''>due</span> <span style=''>to</span> <span style=''>Kallenberg</span> <span style=''>(2009)</span> <span style=''>and</span> <span style=''>obtained</span> <span style=''>a</span> <span style=''>network</span> <span style=''>m ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Bounded</span> <span style=''>Optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Exploration</span> <span style=''>in</span> <span style=''>MDP</span> <br/><br/><span style=''>Within</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>probably</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximately</span> <span style=''>correct</span> <span style=''>Markov</span> <span style=''>decision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>(PAC</span> <span style=''>MDP)</span> <span style=''>much</span> <span style='background-color:rgba(255, 0, 0, 0.38530066815144776);'>theoretical</span> <span style=''>work</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>attain</span> <span style=''>near</span> <span style='background-color:rgba(255, 0, 0, 0.34615384615384615);'>optimality</span> <span style=''>after</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>long</span> <span style=''>period</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploration</span> <span style=''>However</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>concerns</span> <span style=''>require</span> <span style=''>the</span> <span style=''>attainment</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.8);'>satisfactory</span> <span style=''>behavior</span> <span style=''>within</span> <span style=''>a</span> <span style=''>short</span> <span style=''>period</span> <span style=''>of</span> <span style=''>time</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>relax</span> <span style=''>the</span> <span style=''>PAC</span> <span style=''>MDP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.6000000000000001);'>reconcile</span> <span style='background-color:rgba(255, 0, 0, 0.30909090909090897);'>theoretically</span> <span style=''>driven</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploration</span> <span style=''>methods</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>needs</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>discrete</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>state</span> <span style=''>spaces</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.31372549019607837);'>illustrate</span> <span style=''>the</span> <span style=''>benefits</span> <span style=''>of</span> <span style=''>our</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relaxation</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.38530066815144776);'>theoretical</span> <span style=''>analyses</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.4026845637583892);'>numerical</span> <span style=''>examples</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>also</span> <span style=''>maintain</span> <span style=''>anytime</span> <span style=''>error</span> <span style=''>bounds</span> <span style=''>and</span> <span style=''>average</span> <span style=''>loss</span> <span style=''>bounds</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Extraction</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Automated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <span style=''>of</span> <span style=''>Heartbeats</span> <span style=''>by</span> <span style=''>Machine</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>of</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>heart</span> <span style=''>arrhythmias</span> <span style=''>with</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>eventual</span> <span style=''>adoption</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practicing</span> <span style=''>cardiologists</span> <span style=''>In</span> <span style=''>clinical</span> <span style=''>practice</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>small</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>meaningful</span> <span style=''>features</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extracted</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heartbeat</span> <span style=''>cycle</span> <span style=''>However</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>use</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>vectors</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consisting</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>morphological</span> <span style=''>and</span> <span style=''>time</span> <span style=''>based</span> <span style=''>features</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>electrocardiogram</span> <span style=''>(ECG)</span> <span style=''>signals</span> <span style=''>we</span> <span style=''>found</span> <span style=''>smaller</span> <span style=''>subsets</span> <span style=''>of</span> <span style=''>features</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>arrhythmias</span> <span style=''>with</span> <span style=''>high</span> <span style=''>accuracy</span> <span style=''>The</span> <span style=''>features</span> <span style=''>were</span> <span style=''>found</span> <span style=''>by</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style=''>step</span> <span style=''>wise</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>method</span> <span style=''>We</span> <span style=''>depart</span> <span style=''>from</span> <span style=''>common</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style=''>aspects</span> <span style=''>1</span> <span style=''>As</span> <span style=''>opposed</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.23944661227385597)
# 	architecture (0.09365023057821922)
# 	representation (0.13444483859524653)
# 	challenging (0.11174175239446613)
# 	different (0.2617949627527492)
# 	segmentation (0.07697765164952111)
# 	detection (0.11848173111032281)
# 	experimental (0.15218162468960625)
# 	recognition (0.13550904576090814)
# 	convolutional (0.14508691025186235)
#
# Some Statistics words are:
# 	stochastic (0.1408379606259465)
# 	algorithm (0.38768298838970217)
# 	statistical (0.16102978293791015)
# 	estimation (0.1701161029782938)
# 	variables (0.1474003028773347)
# 	theoretical (0.15699141847551742)
# 	distribution (0.19081272084805653)
# 	dimensional (0.19232710752145382)
# 	inference (0.20747097425542654)
# 	regression (0.18374558303886926)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a236da16-6633-4d73-adcf-af389ad4d1d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a236da16-6633-4d73-adcf-af389ad4d1d7")) {                    Plotly.newPlot(                        "a236da16-6633-4d73-adcf-af389ad4d1d7",                        [{"x":["generating","constructing","construction","embedding","understanding","sentences","concerned","classifier","furthermore","generative","classification","generated","classifying","necessarily","including","inference","accuracies","distinguishability","comparing","hypothesis","important","characteristics","completed","projective","parameter","framework","representation","ultrametric","associated","calculate","stochastic","dendrogram","algebraic","implications","distributions","robustness","applications","complementary","dimensional","algorithms","minimizing","underlying","dissertation","explicitly","discriminative","structure","distortions","information","probabilistic","specifically","experiments","available","complexity","graphical","structures","insufficient","particularly","insufficiency","iterative","categories","approximate","challenge","development","resulting","determined","correlated","projections","designing","correlations","conditional","probability","representations","significant","acquisition","answering","techniques","candidates","randomised","contextual","abstracts","automatically","candidate","structural","annotated","processing","summarisation","automated","supervised","performed","extracting","extraction","controlled","interpretable","optimization","estimates","restricts","posterior","procedure","introduce","typically","inferring","regression","construct","solutions","compositional","discovery","confident","uncertainty","preserving","additional","predictions","resolution","prediction","satellite","directions","increased","approaches","availability","outperform","challenges","boundaries","segmentation","introducing","translation","recognition","unweighted","successfully","averaging","investigated","stochastically","different","ensembles","performance","convolutional","artificial","confidence","phenomenon","improvement","assumptions","application","guarantees","convergent","consisting","maximization","estimation","expectation","compressed","deconvolution","spatiotemporally","innovations","theoretical","transition","efficient","transient","simulation","advantage","frequently","conducted","presented","structured","constraint","dictionary","developed","addresses","computational","efficiency","encouraged","difference","extensive","suppression","regularization","categorization","meanwhile","efficiently","properties","literature","observation","partitioning","sufficiently","asymptotic","statistics","algorithm","significantly","synthetic","numerical","processes","considered","estimated","densities","iteration","clustering","initialization","knowledge","according","dissimilarity","stationary","observations","nonparametric","guaranteed","estimating","converges","noiseless","estimator","nonconvex","illustrate","statistical","superiority","appropriate","completion","outperforms","corroborate","experimental","demonstrate","aggregates","practical","covariance","criterion","increments","particular","consistent","respectively","unsupervised","fractional","annotations","transferring","detection","finetuning","neighbors","localizing","additionally","correcting","differences","keypoints","especially","simultaneously","neighborhood","independent","similarities","projection","quantization","inferences","parameters","interface","approximations","performing","sufficient","mechanisms","differentially","randomness","variational","intractable","mechanism","corresponding","likelihood","inaccurat ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	ultrametric
# 	dendrogram
# 	increments
# 	likelihoods
# 	intractability
# 	heteroscedasticity
# 	heteroscedastic
# 	semiparametric
# 	straightforwardly
# 	reproduces
# 	similitude
# 	oscillates
# 	refitting
# 	tractography
# 	forecasters
# 	pediatric
# 	degenerate
# 	resistance
# 	manifested
# 	integrative
# Some words which never appear in Statistics papers:
# 	randomised
# 	summarisation
# 	suppression
# 	finetuning
# 	localizing
# 	keypoints
# 	pedestrian
# 	accelerator
# 	conflicts
# 	audiences
# 	multifaceted
# 	reflection
# 	territory
# 	deformation
# 	multiplicity
# 	deceptive
# 	unaffected
# 	subsequences
# 	recurring
# 	discriminability

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.053714844107858e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7458333333333333
